# %% [markdown]
# # Extracting Data from a PDF using PyPDF2 Library

# %%
pip install PyPDF2

# %%
from PyPDF2 import PdfReader

reader = PdfReader(pdf_file)
page = reader.pages[3]  # example page
print(page.extract_text())

# %%
import re

pattern = r"(\d{12})\s+(.+?)\s+(\d+)\s+(\d+)\s+([\d.]+)\s+([\d.]+)\s+(\d+)"

rows = re.findall(pattern, page)
print(rows)

# %%
from PyPDF2 import PdfReader

reader = PdfReader(pdf_file)

full_text = ""
for page in reader.pages:
    full_text += page.extract_text() + "\n"

print(full_text)

# %%
import re

pattern = r"(\d{12})\s+(.+?)\s+(\d+)\s+(\d+)\s+([\d.]+)\s+([\d.]+)\s+(\d+)"

rows = re.findall(pattern, full_text)
print(rows)

# %%
import pandas as pd

df = pd.DataFrame(rows, columns=[
 column_names])
df.head()

# %%
df.to_csv("polling_data.csv", index=False)
